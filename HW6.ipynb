# %%
# !spades.py -1 ~/0_python_projects/ngs_HW6/data/illumina.100x.1.fq -2 ~/0_python_projects/ngs_HW6/data/illumina.100x.2.fq -o ~/0_python_projects/ngs_HW6/output_Illumina

#10x
# !/Users/dashabalashova/ngs_2/canu-1-1.8/Darwin-amd64/bin/canu -p pb_10x -d output_pacbio_10x genomeSize=4.8m stopOnLowCoverage=6 useGrid=false -pacbio-raw ~/0_python_projects/ngs_HW6/data/pacbio_10x.fq

#20x
# !/Users/dashabalashova/ngs_2/canu-1-1.8/Darwin-amd64/bin/canu -p pb_20x -d output_pacbio_20x genomeSize=4.8m stopOnLowCoverage=6 useGrid=false -pacbio-raw ~/0_python_projects/ngs_HW6/data/pacbio_20x.fq

#40x
# !/Users/dashabalashova/ngs_2/canu-1-1.8/Darwin-amd64/bin/canu -p pb_40x -d output_pacbio_40x genomeSize=4.8m useGrid=false -pacbio-raw ~/0_python_projects/ngs_HW6/data/pacbio_40x.fq

#80x
# !/Users/dashabalashova/ngs_2/canu-1-1.8/Darwin-amd64/bin/canu -p pb_80x -d output_pacbio_80x genomeSize=4.8m useGrid=false -pacbio-raw ~/0_python_projects/ngs_HW6/data/pacbio_80x.fq
# Out:
# -- Canu 1.8
# --
# -- CITATIONS
# --
# -- Koren S, Walenz BP, Berlin K, Miller JR, Phillippy AM.
# -- Canu: scalable and accurate long-read assembly via adaptive k-mer weighting and repeat separation.
# -- Genome Res. 2017 May;27(5):722-736.
# -- http://doi.org/10.1101/gr.215087.116
# --
# -- Koren S, Rhie A, Walenz BP, Dilthey AT, Bickhart DM, Kingan SB, Hiendleder S, Williams JL, Smith TPL, Phillippy AM.
# -- De novo assembly of haplotype-resolved genomes with trio binning.
# -- Nat Biotechnol. 2018
# -- https//doi.org/10.1038/nbt.4277
# --
# -- Read and contig alignments during correction, consensus and GFA building use:
# --   Šošic M, Šikic M.
# --   Edlib: a C/C ++ library for fast, exact sequence alignment using edit distance.
# --   Bioinformatics. 2017 May 1;33(9):1394-1395.
# --   http://doi.org/10.1093/bioinformatics/btw753
# --
# -- Overlaps are generated using:
# --   Berlin K, et al.
# ...

# %%
# !spades.py -1 ~/0_python_projects/ngs_HW6/data/illumina.100x.1.fq -2 ~/0_python_projects/ngs_HW6/data/illumina.100x.2.fq --pacbio ~/0_python_projects/ngs_HW6/data/pacbio_10x.fq -o ~/0_python_projects/ngs_HW6/illumina_pb10x
# !spades.py -1 ~/0_python_projects/ngs_HW6/data/illumina.100x.1.fq -2 ~/0_python_projects/ngs_HW6/data/illumina.100x.2.fq --pacbio ~/0_python_projects/ngs_HW6/data/pacbio_20x.fq -o ~/0_python_projects/ngs_HW6/illumina_pb20x
# !spades.py -1 ~/0_python_projects/ngs_HW6/data/illumina.100x.1.fq -2 ~/0_python_projects/ngs_HW6/data/illumina.100x.2.fq --pacbio ~/0_python_projects/ngs_HW6/data/pacbio_40x.fq -o ~/0_python_projects/ngs_HW6/illumina_pb40x
# !spades.py -1 ~/0_python_projects/ngs_HW6/data/illumina.100x.1.fq -2 ~/0_python_projects/ngs_HW6/data/illumina.100x.2.fq --pacbio ~/0_python_projects/ngs_HW6/data/pacbio_80x.fq -o ~/0_python_projects/ngs_HW6/illumina_pb80x
# Out:
# Command line: /Users/dashabalashova/ngs/SPAdes-3.13.0-Darwin/bin/spades.py	-1	/Users/dashabalashova/0_python_projects/ngs_HW6/data/illumina.100x.1.fq	-2	/Users/dashabalashova/0_python_projects/ngs_HW6/data/illumina.100x.2.fq	--pacbio	/Users/dashabalashova/0_python_projects/ngs_HW6/data/pacbio_40x.fq	-o	/Users/dashabalashova/0_python_projects/ngs_HW6/illumina_pb40x
#
# System information:
#   SPAdes version: 3.13.0
#   Python version: 3.6.5
#   OS: Darwin-17.4.0-x86_64-i386-64bit
#
# Output dir: /Users/dashabalashova/0_python_projects/ngs_HW6/illumina_pb40x
# Mode: read error correction and assembling
# Debug mode is turned OFF
#
# Dataset parameters:
#   Multi-cell mode (you should set '--sc' flag if input data was obtained with MDA (single-cell) technology or --meta flag if processing metagenomic dataset)
#   Reads:
#     Library number: 1, library type: paired-end
#       orientation: fr
# ...

# %%
# !quast.py -o ~/0_python_projects/ngs_HW6/output_quast_4 -r ~/0_python_projects/ngs_HW6/data/reference.fasta ~/0_python_projects/ngs_HW6/output_Illumina/contigs.fasta ~/0_python_projects/ngs_HW6/output_pacbio_10x/pb_10x.contigs.fasta ~/0_python_projects/ngs_HW6/output_pacbio_20x/pb_20x.contigs.fasta ~/0_python_projects/ngs_HW6/output_pacbio_40x/pb_40x.contigs.fasta ~/0_python_projects/ngs_HW6/output_pacbio_80x/pb_80x.contigs.fasta ~/0_python_projects/ngs_HW6/illumina_pb10x/contigs.fasta ~/0_python_projects/ngs_HW6/illumina_pb20x/contigs.fasta ~/0_python_projects/ngs_HW6/illumina_pb40x/contigs.fasta ~/0_python_projects/ngs_HW6/illumina_pb80x/contigs.fasta -l illumina,pacbio10x,pacbio20x,pacbio40x,pacbio80x,il_pb10x,il_pb20x,il_pb40x,il_pb80x
# Out:
# /Users/dashabalashova/miniconda3/lib/python3.6/site-packages/quast-5.0.2-py3.6.egg/EGG-INFO/scripts/quast.py -o /Users/dashabalashova/0_python_projects/ngs_HW6/output_quast_4 -r /Users/dashabalashova/0_python_projects/ngs_HW6/data/reference.fasta /Users/dashabalashova/0_python_projects/ngs_HW6/output_Illumina/contigs.fasta /Users/dashabalashova/0_python_projects/ngs_HW6/output_pacbio_10x/pb_10x.contigs.fasta /Users/dashabalashova/0_python_projects/ngs_HW6/output_pacbio_20x/pb_20x.contigs.fasta /Users/dashabalashova/0_python_projects/ngs_HW6/output_pacbio_40x/pb_40x.contigs.fasta /Users/dashabalashova/0_python_projects/ngs_HW6/output_pacbio_80x/pb_80x.contigs.fasta /Users/dashabalashova/0_python_projects/ngs_HW6/illumina_pb10x/contigs.fasta /Users/dashabalashova/0_python_projects/ngs_HW6/illumina_pb20x/contigs.fasta /Users/dashabalashova/0_python_projects/ngs_HW6/illumina_pb40x/contigs.fasta /Users/dashabalashova/0_python_projects/ngs_HW6/illumina_pb80x/contigs.fasta -l illumina,pacbi
# ...
