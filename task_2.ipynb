# %%
from Bio import SeqIO
import matplotlib.pyplot as plt
import time
import seaborn as sns
import pandas as pd
t_s=time.time()
import numpy as np

le=100

a=[0]*100
b=[0]*100

a2 = [0]*100
b2 = [0]*100

c1 = 0
c2 = [0.001]*100

df = pd.DataFrame()
m = 1
f=[]
for n in range(0, le):
    e=[]
    t_s=time.time()
    for record in SeqIO.parse("100x.1.fastq", "fastq"):
        
        d = record.letter_annotations["phred_quality"][n]

        e.append(10**(-(d/10)))

    f.append(np.mean(e))
    
sns.lineplot(data=pd.DataFrame(f))
