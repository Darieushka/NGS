# %%
#!wget http://spades.bioinf.spbau.ru/students/2b/B22-730.fastq.gz -O ~/ngs_institute/data/B22-730.fastq.gz
#!gunzip ~/ngs_institute/data/B22-730.fastq.gz



#!wget http://spades.bioinf.spbau.ru/students/2b/DH10B-K12.fasta -O ~/ngs_institute/data/DH10B-K12.fasta


# !wget http://spades.bioinf.spbau.ru/students/2b/C24-698.fastq.gz -O ~/ngs_institute/data/C24-698.fastq.gz
# !gunzip ~/ngs_institute/data/C24-698.fastq.gz
# Out:
# --2019-03-09 14:21:45--  http://spades.bioinf.spbau.ru/students/2b/C24-698.fastq.gz
# Resolving spades.bioinf.spbau.ru (spades.bioinf.spbau.ru)... 194.85.238.21
# Connecting to spades.bioinf.spbau.ru (spades.bioinf.spbau.ru)|194.85.238.21|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 97418857 (93M) [application/x-gzip]
# Saving to: <</Users/dashabalashova/ngs_institute/data/C24-698.fastq.gz>>
#
# /Users/dashabalasho 100%[===================>]  92.91M  1.36MB/s    in 73s
#
# 2019-03-09 14:22:58 (1.27 MB/s) - <</Users/dashabalashova/ngs_institute/data/C24-698.fastq.gz>> saved [97418857/97418857]

# %%
#!bowtie2-build ~/ngs_institute/data/DH10B-K12.fasta DH10B-K12_index


# !bwa index -a bwtsw ~/ngs_institute/data/DH10B-K12.fasta
# Out:
# [bwa_index] Pack FASTA... 0.06 sec
# [bwa_index] Construct BWT for the packed sequence...
# [BWTIncCreate] textLength=9372274, availableWord=11906236
# [bwt_gen] Finished constructing BWT in 5 iterations.
# [bwa_index] 2.44 seconds elapse.
# [bwa_index] Update BWT... 0.06 sec
# [bwa_index] Pack forward-only FASTA... 0.03 sec
# [bwa_index] Construct SA from BWT and Occ... 0.71 sec
# [main] Version: 0.7.17-r1188
# [main] CMD: bwa index -a bwtsw /Users/dashabalashova/ngs_institute/data/DH10B-K12.fasta
# [main] Real time: 3.439 sec; CPU: 3.330 sec

# %%
#! cd ~/ngs_institute/data
#!bowtie2 -x DH10B-K12_index -U ~/ngs_institute/data/B22-730.fastq -S B22-730.sam

#!bowtie2 -x DH10B-K12_index -U ~/ngs_institute/data/C24-698.fastq -S C24-698.sam

# !bwa mem ~/ngs_institute/data/DH10B-K12.fasta ~/ngs_institute/data/C24-698.fastq > C24-698_bwamem.sam
# Out:
# [M::bwa_idx_load_from_disk] read 0 ALT contigs
# [M::process] read 40748 sequences (10000257 bp)...
# [M::process] read 40830 sequences (10000256 bp)...
# [M::mem_process_seqs] Processed 40748 reads in 4.890 CPU sec, 4.895 real sec
# [M::process] read 40678 sequences (10000475 bp)...
# [M::mem_process_seqs] Processed 40830 reads in 4.816 CPU sec, 4.712 real sec
# [M::process] read 40934 sequences (10000123 bp)...
# [M::mem_process_seqs] Processed 40678 reads in 5.827 CPU sec, 5.759 real sec
# [M::process] read 40668 sequences (10000353 bp)...
# [M::mem_process_seqs] Processed 40934 reads in 4.382 CPU sec, 4.289 real sec
# [M::process] read 40714 sequences (10000220 bp)...
# [M::mem_process_seqs] Processed 40668 reads in 4.679 CPU sec, 4.746 real sec
# [M::process] read 40714 sequences (10000207 bp)...
# [M::mem_process_seqs] Processed 40714 reads in 5.148 CPU sec, 5.159 real sec
# [M::process] read 40584 sequences (10000468 bp)...
# ...

# %%
#!samtools flagstat B22-730.sam
#!samtools view -S -b B22-730.sam > B22-730.bam
#!samtools sort B22-730.bam > B22-730.sorted.bam
#!samtools index B22-730.sorted.bam
#!bamCoverage -b B22-730.sorted.bam -bs 1000 -o B22-730_1000.bw --outFileFormat bedgraph
#!bamCoverage -b B22-730.sorted.bam -bs 1 -o B22-730.bw --outFileFormat bedgraph

# !samtools flagstat C24-698.sam
# !samtools view -S -b C24-698.sam > C24-698.bam
# !samtools sort C24-698.bam > C24-698.sorted.bam
# !samtools index C24-698.sorted.bam
# !bamCoverage -b C24-698.sorted.bam -bs 1000 -o C24-698_1000.bw --outFileFormat bedgraph
# !bamCoverage -b C24-698.sorted.bam -bs 1 -o C24-698.bw --outFileFormat bedgraph
# Out:
# 685406 + 0 in total (QC-passed reads + QC-failed reads)
# 0 + 0 secondary
# 0 + 0 supplementary
# 0 + 0 duplicates
# 680266 + 0 mapped (99.25% : N/A)
# 0 + 0 paired in sequencing
# 0 + 0 read1
# 0 + 0 read2
# 0 + 0 properly paired (N/A : N/A)
# 0 + 0 with itself and mate mapped
# 0 + 0 singletons (N/A : N/A)
# 0 + 0 with mate mapped to a different chr
# 0 + 0 with mate mapped to a different chr (mapQ>=5)
# bamFilesList: ['C24-698.sorted.bam']
# binLength: 1000
# numberOfSamples: None
# blackListFileName: None
# skipZeroOverZero: False
# defaultFragmentLength: read length
# numberOfProcessors: 1
# verbose: False
# region: None
# bedFile: None
# minMappingQuality: None
# ignoreDuplicates: False
# chrsToSkip: []
# stepSize: 1000
# center_read: False
# samFlag_include: None
# samFlag_exclude: None
# minFragmentLength: 0
# maxFragmentLength: 0
# zerosToNans: False
# smoothLength: None
# save_data: False
# out_file_for_raw_data: None
# maxPairedFragmentLength: 1000
# ...

# %%
# !samtools flagstat C24-698_bwamem.sam
# !samtools view -S -b C24-698_bwamem.sam > C24-698_bwamem.bam
# !samtools sort C24-698_bwamem.bam > C24-698_bwamem.sorted.bam
# !samtools index C24-698_bwamem.sorted.bam
# !bamCoverage -b C24-698_bwamem.sorted.bam -bs 1000 -o C24-698_1000_bwamem.bw --outFileFormat bedgraph
# !bamCoverage -b C24-698_bwamem.sorted.bam -bs 1 -o C24-698_bwamem.bw --outFileFormat bedgraph
# Out:
# 686667 + 0 in total (QC-passed reads + QC-failed reads)
# 0 + 0 secondary
# 1261 + 0 supplementary
# 0 + 0 duplicates
# 682638 + 0 mapped (99.41% : N/A)
# 0 + 0 paired in sequencing
# 0 + 0 read1
# 0 + 0 read2
# 0 + 0 properly paired (N/A : N/A)
# 0 + 0 with itself and mate mapped
# 0 + 0 singletons (N/A : N/A)
# 0 + 0 with mate mapped to a different chr
# 0 + 0 with mate mapped to a different chr (mapQ>=5)
# bamFilesList: ['C24-698_bwamem.sorted.bam']
# binLength: 1000
# numberOfSamples: None
# blackListFileName: None
# skipZeroOverZero: False
# defaultFragmentLength: read length
# numberOfProcessors: 1
# verbose: False
# region: None
# bedFile: None
# minMappingQuality: None
# ignoreDuplicates: False
# chrsToSkip: []
# stepSize: 1000
# center_read: False
# samFlag_include: None
# samFlag_exclude: None
# minFragmentLength: 0
# maxFragmentLength: 0
# zerosToNans: False
# smoothLength: None
# save_data: False
# out_file_for_raw_data: None
# maxPairedFragmentLength: 1000
# ...
